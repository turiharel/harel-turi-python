# %%
my_name = "harel"
my_age = 13
my_height = 1.68
likes_python = True

print("Type of my_name:", type(my_name))
print("Type of my_age:", type(my_age))
print("Type of my_height:", type(my_height))
print("Type of likes_python:", type(likes_python))

age = 13

age_months = age * 12
age_days = age * 365
age_hours = age * 365 * 24

print(f"I am {age_months} months old")
print(f"I am {age_days} days old")
print(f"I am {age_hours} hours old")

text_number = "42"

text_number = int(text_number)

text_number = text_number + 8

text_number = str(text_number)

print("The answer is", text_number,)

result1 = 17 / 5
print("17 / 5 =", result1)

result2 = 17 // 5
print("17 // 5 =", result2)

result3 = 17 % 5
print("17 % 5 =", result3)

number1 = 15
number2 = 28
number3 = 7

remainder1 = number1 % 2
remainder2 = number2 % 2
remainder3 = number3 % 2

print(f"{number1} divided by 2 has remainder: {remainder1}")
print(f"{number2} divided by 2 has remainder: {remainder2}")
print(f"{number3} divided by 2 has remainder: {remainder3}")

name = input("What is your name? ")
age = int(input("How old are you? "))

future_age = age + 10

print(f"Hello {name}! In 10 years you will be {future_age} years old.")

item1 = float(input("Price of first item: $"))
item2 = float(input("Price of second item: $"))
item3 = float(input("Price of third item: $"))

total = item1 + item2 + item3

has_discount = input("Do you have a discount coupon? (yes/no): ")


if has_discount == "yes":
    discount = total * 0.85
    price = discount * 1.08
    print("evrething is", total,"with discount it", discount, "with tax it", price,)
else:
    price = total * 1.08
    print("evrething is", total, "with tax it", price,)

age_months = age * 12
age_weeks = age * 52
age_days = age * 365
age_hours = age_days * 24
age_minutes = age_hours * 60
age_seconds = age_minutes * 60

weight = float(input("what is your weight"))
height = float(input("what is your height"))

BMI = weight / height ** 2

print("your BMI is", BMI,)

hours = int(input("give me a number of hours"))

days =  hours / 24
minutes = hours * 60
seconds = minutes * 60

print("you wrote", hours, "hours that are", days, "days", minutes, "minutes and", seconds, "seconds")

radius = float(input("give me radius of a circle")) 

circumference =  2 *  3.14159 * radius 
area = 3.14159 * radius ** 2

print("the circumference for the radius you chose is", circumference, "and the area is", area,)

money_save = float(input("how much money do you save per week"))

month = money_save * 4
months6 = month * 6
year = months6 * 2

interest_month = month * 1.05
interest_months6 = months6 * 1.05
interest_year = year * 1.05

print("if you save for a month you have", month, "for 6 months", months6, "and for a year", year,)
print("if you save for a month with 5% interest you have", interest_month, "for 6 months", interest_months6, "and for a year", interest_year,)
# Out:
# Type of my_name: <class 'str'>
# Type of my_age: <class 'int'>
# Type of my_height: <class 'float'>
# Type of likes_python: <class 'bool'>
# I am 156 months old
# I am 4745 days old
# I am 113880 hours old
# The answer is 50
# 17 / 5 = 3.4
# 17 // 5 = 3
# 17 % 5 = 2
# 15 divided by 2 has remainder: 1
# 28 divided by 2 has remainder: 0
# 7 divided by 2 has remainder: 1
# Hello harel! In 10 years you will be 23 years old.
# evrething is 203.69 with discount it 173.13649999999998 with tax it 186.98742
# your BMI is 15.09353741496599
# you wrote 679 hours that are 28.291666666666668 days 40740 minutes and 2444400 seconds
# the circumference for the radius you chose is 425.30845419999997 and the area is 14394.564632398999
# if you save for a month you have 3904.0 for 6 months 23424.0 and for a year 46848.0
# if you save for a month with 5% interest you have 4099.2 for 6 months 24595.2 and for a year 49190.4
