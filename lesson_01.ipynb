# %%
print("Hello World!")
print("my name is harel")
print("I am 13 years old")

result  = 3 * 7 + 10
print(result)

my_age = 13
friend_age = 13

total = 13+13


difference = 13-13

print("The sum is:", total)
print("The difference is:", difference)

name = "harel"
age = 13

print("My name is", name, "and I am", age, "years old")

print(f"My name is {name} and I am {age} years old")

power = 2**10
print("2 to the power of 10 =", power)

division = 50//7
print("50 divided by 7 (integer) =", division)

remainder  = 50%7
print("The remainder is:", remainder)

name = input("What is your name? ")

age = int(input("How old are you? "))

till100 = 100 - age
print("Hello", name, "now you are", age, "years old untill 100 years old you has", till100, "years to live")

# Space for your homework

bill = int(input("how much is the bill"))

tip = int(input("how much to tip"))
print("the tip is", bill*tip/100)


C = int(input("what the temperature in Celsius"))

f =  C * 9/5 + 32
print("the temperature in Fahrenheit is", f,)


print("you has lived", age*365*24*60*60,"seconds")
# Out:
# Hello World!
# my name is harel
# I am 13 years old
# 31
# The sum is: 26
# The difference is: 0
# My name is harel and I am 13 years old
# My name is harel and I am 13 years old
# 2 to the power of 10 = 1024
# 50 divided by 7 (integer) = 7
# The remainder is: 1
# Hello harel now you are 13 years old untill 100 years old you has 87 years to live
# the tip is 100.0
# the temperature in Fahrenheit is 93.2
# you has lived 409968000 seconds
