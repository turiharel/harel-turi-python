# %%
full_name = "harel turi"

print(full_name[0])
print(full_name[-1])
print(len(full_name))

text = "Programming is fun"

print(text[:11])
print(text[-3:])
print(text[::2])
print(text[::-1])

name = input("Enter your name: ")

name = name.strip()
name = name.title()

print("hi", name,)

sentence = input("give me a sentence")

sentence = sentence.split()
print(len(sentence))

email_address = input("give me your email address")

if email_address.find("@") and email_address.find("."):
    print("Valid email")
else:
    print("Invalid email")

sentence1 = input("give me a sentence")
word = input("give me a word to find in sentence")
replace = input("what word to replace it with")

sentence2 = sentence1.replace(word , replace)

print("the original sentences is", sentence1, "and the modified sentences is", sentence2,)

sentence1 = sentence1.replace("a" , "4")
sentence1 = sentence1.replace("e" , "3")
sentence1 = sentence1.replace("i" , "1")
sentence1 = sentence1.replace("o" , "0")
sentence1 = sentence1.replace("u" , "7")

print(sentence1)

# Space for your homework

first  = input("what your first name")
last = input("what your last name")

print(first.upper())
print(first.lower())
print(first.title())
print(first.swapcase())

print(last.upper())
print(last.lower())
print(last.title())
print(last.swapcase())

full  = input("what your full name")

full = full.split()

print(full[0][0], ".", full[1][0], ".")

password  = input("what your password")

if len(password) < 8 or password.isalpha() or password.isdigit(): 
    print("password is weak")
else:
     print("password is Strong")
# Out:
# h
# i
# 10
# Programming
# fun
# Pormigi u
# nuf si gnimmargorP
# hi Harel Turi
# 3
# Valid email
# the original sentences is I learn python today and the modified sentences is harel learn python today
# I l34rn pyth0n t0d4y
# HAREL
# harel
# Harel
# HAREL
# TURI
# turi
# Turi
# TURI
# h . t .
# password is Strong
