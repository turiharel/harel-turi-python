# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 > num2:
    print("number 1 is larger")
elif num1 < num2:
    print("number 2 is larger")
else:
    print("The numbers are equal")

number  = int(input("Enter number: "))

if  number < 0:
    print("number is negative")
else:
    print("number is positive")

if number % 2 == 0:
    print("number is even")
else:
    print("number is odd")

age = int(input("Enter age: "))

if age > 0 and age <=12:
    print("Child")
elif age > 13 and age <= 19:
    print("Teenager")
elif age > 20 and age <= 64:
    print("Adult")
elif age > 65:
    print("Senior")

score = int(input("Enter score: "))

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")

password = 7011

password1 = int(input("Enter password: "))

if password == 7011:
    print("Access granted")
else:
    print("Access denied")

if password <= 6:
    print("password is at least 6 characters long")
else:
    print("password isn't 6 characters long")

num3 = int(input("Enter first number: "))
num4 = int(input("Enter second number: "))
operation = str(input("Enter operation : "))

if operation == "+":
    calculation1 = num3 + num4
    print(calculation1)
elif operation == "-":
    calculation2 = num3 - num4
    print(calculation2)
elif operation == "*":
    calculation3 = num3 * num4
    print(calculation3)
elif operation == "/":
    calculation4 = num3 / num4
    print(calculation4)
elif operation == "/" and num3 == 0 or num4 == 0:
    print("error message")

# Space for your homework

username = "m.r turi"
password = "turi7011"

password1 = input("Enter password: ")
username1 = input("Enter username: ")

if username == username1 and password1 == username:
    print("Access granted")
else:
    print("Access denied")

temperature = int(input("Enter temperature: "))

if temperature <= 10:
    print("Wear a jacket")
elif temperature <= 20:
    print("Wear a sweater")
elif temperature <= 30:
    print("T-shirt weather")
else:
    print("Stay cool!")

year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 > 0) or (year % 100 == 0 and year % 400 == 0):
    print("it is a leap year")
else:
    print("it isn't a leap year")
# Out:
# The numbers are equal
# number is negative
# number is even
# Grade: A
# Access granted
# password isn't 6 characters long
# 0.36507936507936506
# Access denied
# T-shirt weather
# it isn't a leap year
